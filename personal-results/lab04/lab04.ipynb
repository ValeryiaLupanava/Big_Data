# %% [markdown]
# ### Вводные данные для обучения

# %% [markdown]
# Объявление применяеных библиотек

# %%
#!/opt/anaconda/envs/bd9/bin/python

import os
import pandas as pd
import numpy as np
import seaborn as sns # Для визуализации данных.
import matplotlib.pyplot as plt
# Параметр, позволяющий визуализировать графики без show()
# %matplotlib inline 
from sklearn import preprocessing

# %% [markdown]
# Объявление директорий для train и test-набора

# %%
home_dir = '/data/share/lab04data'

train_file = "lab04_train.csv"
test_file = "lab04_test.csv"

train_dir = home_dir+'/'+train_file
test_dir = home_dir+'/'+test_file

print(home_dir+'/'+train_file)
# Out:
# /data/share/lab04data/lab04_train.csv

# %% [markdown]
# Вывод данных train-набора

# %%
train_df = pd.read_csv (train_dir)
train_df.tail(10)
# Out:
#         Unnamed: 0      ID  CR_PROD_CNT_IL  AMOUNT_RUB_CLO_PRC  \
# 320754       83534  230375               0                 NaN
# 320755      228984  375825               0            0.000000
# 320756      367774  514615               1                 NaN
# 320757      193334  340175               1            0.000000
# 320758       13300  160141               0            0.000000
# 320759      351454  498295               0            0.000000
# 320760      421102  567943               0            0.143985
# 320761      360104  506945               0            0.043560
# 320762      180350  327191               0            0.007867
# 320763      222683  369524               0            0.019900
#
#         PRC_ACCEPTS_A_EMAIL_LINK  APP_REGISTR_RGN_CODE  PRC_ACCEPTS_A_POS  \
# 320754                       NaN                   NaN                NaN
# 320755                       0.0                   NaN                0.0
# 320756                       NaN                   NaN                NaN
# 320757                       NaN                   NaN                NaN
# 320758                       NaN                   NaN                NaN
# 320759                       NaN                  42.0                NaN
# 320760                       0.0                   NaN                0.0
# 320761                       NaN                   NaN                NaN
# 320762                       0.0                   NaN                0.0
# 320763                       NaN                   NaN                NaN
#
#         PRC_ACCEPTS_A_TK  TURNOVER_DYNAMIC_IL_1M  CNT_TRAN_AUT_TENDENCY1M  \
# 320754               NaN                     0.0                      NaN
# 320755               0.0                     0.0                      NaN
# 320756               NaN                     0.0                      NaN
# 320757               NaN                     0.0                      NaN
# 320758               NaN                     0.0                    0.125
# 320759               NaN                     0.0                      NaN
# 320760               0.0                     0.0                      NaN
# 320761               NaN                     0.0                      NaN
# 320762               0.0                     0.0                      NaN
# 320763               NaN                     NaN                      NaN
#
#          ...    REST_DYNAMIC_CC_3M  MED_DEBT_PRC_YWZ  LDEAL_ACT_DAYS_PCT_TR3  \
# 320754   ...                   0.0               NaN                     NaN
# 320755   ...                   0.0               0.0                0.000000
# 320756   ...                   0.0               NaN                     NaN
# 320757   ...                   0.0               0.0                0.132616
# 320758   ...                   0.0               NaN                     NaN
# 320759   ...                   0.0               0.0                0.000000
# 320760   ...                   0.0               0.0                0.000000
# 320761   ...                   0.0               NaN                     NaN
# 320762   ...                   0.0               NaN                     NaN
# 320763   ...                   NaN               NaN                     NaN
#
#         LDEAL_ACT_DAYS_PCT_AAVG LDEAL_DELINQ_PER_MAXYWZ  \
# 320754                      NaN                     NaN
# 320755                 0.000000                     0.0
# 320756                      NaN                     NaN
# 320757                 0.132616                     0.0
# 320758                      NaN                     NaN
# 320759                 0.000000                     0.0
# 320760                 0.000000                     0.0
# 320761                      NaN                     NaN
# 320762                      NaN                     NaN
# 320763                      NaN                     NaN
#
#         TURNOVER_DYNAMIC_CC_3M  LDEAL_ACT_DAYS_PCT_TR  LDEAL_ACT_DAYS_PCT_TR4  \
# 320754                     0.0                    NaN                     NaN
# 320755                     0.0               0.000000                0.000000
# 320756                     0.0                    NaN                     NaN
# 320757                     0.0               0.064516                0.064516
# 320758                     0.0                    NaN                     NaN
# 320759                     0.0               0.000000                0.000000
# 320760                     0.0               0.000000                0.000000
# 320761                     0.0                    NaN                     NaN
# 320762                     0.0                    NaN                     NaN
# 320763                     NaN                    NaN                     NaN
#
#         LDEAL_ACT_DAYS_PCT_CURR  TARGET
# 320754                      NaN     1.0
# 320755                 0.000000     0.0
# 320756                      NaN     0.0
# 320757                 0.064516     0.0
# 320758                      NaN     0.0
# 320759                 0.000000     0.0
# 320760                 0.000000     0.0
# 320761                      NaN     1.0
# 320762                      NaN     0.0
# 320763                      NaN     NaN
#
# [10 rows x 117 columns]

# %%
train_df.shape # Количество строк и колонок
# Out:
# (320764, 117)

# %% [markdown]
# ### Обработка данных

# %% [markdown]
# Подсчитывает уникальные значения в колонке TARGET

# %%
train_df['TARGET'].value_counts(dropna=False)
# Out:
#  0.0    294607
#  1.0     26156
# NaN          1
# Name: TARGET, dtype: int64

# %% [markdown]
# В TARGET должны быть точные значения, поэтому заменить нельзя. NaN нужно удалить

# %%
train_df = train_df[train_df['TARGET'].notna()]
train_df.shape
# Out:
# (320763, 117)

# %% [markdown]
# Преобразуем TARGET-значения в int, потому что в колонке только значения 0 и 1

# %%
train_df['TARGET'] = train_df['TARGET'].round(0).astype(int)

# %%
train_df['TARGET'].value_counts(dropna = False)
# Out:
# 0    294607
# 1     26156
# Name: TARGET, dtype: int64

# %% [markdown]
# Проверяю типы данных в таблице

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320763 entries, 0 to 320762
# Columns: 117 entries, Unnamed: 0 to TARGET
# dtypes: float64(100), int64(4), object(13)
# memory usage: 288.8+ MB

# %% [markdown]
# Выводим данные из колонок типа object

# %%
object_columns = train_df.select_dtypes(include=object).columns
train_df.select_dtypes(include=object)
# Out:
#        CLNT_TRUST_RELATION APP_MARITAL_STATUS APP_KIND_OF_PROP_HABITATION  \
# 0                      NaN                NaN                         NaN
# 1                      NaN                NaN                         NaN
# 2                      NaN                NaN                         NaN
# 3                      NaN                NaN                         NaN
# 4                      NaN                NaN                         NaN
# 5                      NaN                NaN                         NaN
# 6                      NaN                NaN                         NaN
# 7                      NaN                  M                        RENT
# 8                   FRIEND                  V                         NaN
# 9                      NaN                NaN                         NaN
# 10                  FRIEND                  M                     NPRIVAT
# 11                     NaN                NaN                         NaN
# 12                     NaN                NaN                         NaN
# 13                  SISTER                  M                          SO
# 14                     NaN                NaN                         NaN
# 15                     NaN                NaN                         NaN
# 16                     NaN                NaN                         NaN
# 17                     NaN                NaN                         NaN
# 18                   OTHER                  M                         NaN
# 19                     NaN                NaN                         NaN
# 20                     NaN                NaN                         NaN
# 21                     NaN                NaN                         NaN
# 22                     NaN                NaN                         NaN
# 23                     NaN                NaN                         NaN
# 24                     NaN                NaN                         NaN
# 25                     NaN                NaN                         NaN
# 26                     NaN                NaN                         NaN
# 27                     NaN                NaN                         NaN
# 28                     NaN                NaN                         NaN
# 29                     NaN                NaN                         NaN
# ...                    ...                ...                         ...
# 320733                 NaN                NaN                         NaN
# 320734                 NaN                NaN                         NaN
# 320735                 NaN                NaN                         NaN
# 320736            DAUGHTER                  D                         NaN
# 320737                 NaN                NaN                         NaN
# 320738                 NaN                NaN                         NaN
# 320739                 NaN                NaN                         NaN
# 320740                 NaN                NaN                         NaN
# 320741                 NaN                NaN                         NaN
# 320742               OTHER                  V                       OTHER
# 320743            RELATIVE                  M                          SO
# 320744                 NaN                NaN                         NaN
# 320745                 NaN                NaN                         NaN
# 320746                 NaN                NaN                         NaN
# 320747                 NaN                NaN                         NaN
# 320748              MOTHER                  M                         NaN
# 320749                 NaN                NaN                         NaN
# 320750                 NaN                NaN                         NaN
# 320751                 NaN                NaN                         NaN
# 320752                 NaN                NaN                         NaN
# 320753                 NaN                NaN                         NaN
# 320754                 NaN                NaN                         NaN
# 320755                 NaN                NaN                         NaN
# 320756              FRIEND                  M                          SO
# 320757              SISTER                  N                          SO
# 320758                 NaN                NaN                         NaN
# 320759              SISTER                  M                          JO
# 320760                 NaN                NaN                         NaN
# 320761                 NaN                NaN                         NaN
# 320762                 NaN                NaN                         NaN
#
#        CLNT_JOB_POSITION_TYPE                  CLNT_JOB_POSITION  \
# 0                         NaN                                NaN
# 1                         NaN                      офис-менеджер
# 2                         NaN                        консультант
# 3                         NaN                                NaN
# 4                         NaN                          экономист
# 5                         NaN                                NaN
# 6                         NaN          Младший научный сотрудник
# 7                         NaN                           ДИРЕКТОР
# 8                     MANAGER                         СПЕЦИАЛИСТ
# 9                         NaN                     глав.бухгалтер
# 10                TOP_MANAGER               начальник отдела ВЭД
# 11                        NaN             Менеджер отдела продаж
# 12                        NaN                          ПЕНСИОНЕР
# 13                    MANAGER                РУКОВОДИТЕЛЬ ОТДЕЛА
# 14                        NaN               менеджер по продажам
# 15                        NaN                                NaN
# 16                        NaN                       РУКОВОДИТЕЛЬ
# 17                        NaN               ГЕНЕРАЛЬНЫЙ ДИРЕКТОР
# 18                        NaN                                NaN
# 19                        NaN                           Директор
# 20                        NaN              Региональный директор
# 21                        NaN                        адмистратор
# 22                        NaN                                NaN
# 23                        NaN                                NaN
# 24                        NaN                           директор
# 25                        NaN                                NaN
# 26                        NaN                        гл. инженер
# 27                        NaN              СТАРШИЙ ПРЕПОДАВАТЕЛЬ
# 28                        NaN                            ГРУЗЧИК
# 29                        NaN                                NaN
# ...                       ...                                ...
# 320733                    NaN                        консультант
# 320734                    NaN                           Директор
# 320735                    NaN                       МЕНЧЕНДАЙЗЕР
# 320736             SPECIALIST                            ИНЖЕНЕР
# 320737                    NaN                исполнит-й продюсер
# 320738                    NaN                              юрист
# 320739                    NaN                         СПЕЦИАЛИСТ
# 320740                    NaN                                NaN
# 320741                    NaN                                NaN
# 320742             SPECIALIST                инженер-программист
# 320743                    NaN            НАЧАЛЬНИК ОТДЕЛА ПРОДАЖ
# 320744                    NaN                      Инженер связи
# 320745                    NaN                                NaN
# 320746                    NaN  руковод. отдела контроля качества
# 320747                    NaN                           ДИРЕКТОР
# 320748                    NaN                ИНЖЕНЕР-ПРОГРАММИСТ
# 320749                    NaN                      ЗАМ ДИРЕКТОРА
# 320750                    NaN                       руководитель
# 320751                    NaN                                NaN
# 320752                    NaN                       ген.директор
# 320753                    NaN              менеджер по поставкам
# 320754                    NaN                            ИНЖЕНЕР
# 320755                    NaN         оператор электро-штабелёра
# 320756                MANAGER                      ЗАМ ДИРЕКТОРА
# 320757                    NaN     ведущий специалист  по рекламе
# 320758                    NaN                              Юрист
# 320759              SELF_EMPL              ЗАМЕСТИТЕЛЬ ДИРЕКТОРА
# 320760                    NaN           зам. начальника отд. ПТО
# 320761                    NaN                           уборщица
# 320762                    NaN                           директор
#
#        APP_DRIVING_LICENSE APP_EDUCATION APP_TRAVEL_PASS APP_CAR  \
# 0                      NaN           NaN             NaN     NaN
# 1                      NaN           NaN             NaN     NaN
# 2                      NaN           NaN             NaN     NaN
# 3                      NaN           NaN             NaN     NaN
# 4                      NaN           NaN             NaN     NaN
# 5                      NaN           NaN             NaN     NaN
# 6                      NaN           NaN             NaN     NaN
# 7                        Y            UH               N       N
# 8                      NaN             H             NaN     NaN
# 9                      NaN           NaN             NaN     NaN
# 10                     NaN             H             NaN     NaN
# 11                     NaN           NaN             NaN     NaN
# 12                     NaN           NaN             NaN     NaN
# 13                       N            HH               N       N
# 14                     NaN           NaN             NaN     NaN
# 15                     NaN           NaN             NaN     NaN
# 16                     NaN           NaN             NaN     NaN
# 17                     NaN           NaN             NaN     NaN
# 18                       N            SS               N       N
# 19                     NaN           NaN             NaN     NaN
# 20                     NaN           NaN             NaN     NaN
# 21                     NaN           NaN             NaN     NaN
# 22                     NaN           NaN             NaN     NaN
# 23                     NaN           NaN             NaN     NaN
# 24                     NaN           NaN             NaN     NaN
# 25                     NaN           NaN             NaN     NaN
# 26                     NaN           NaN             NaN     NaN
# 27                     NaN           NaN             NaN     NaN
# 28                     NaN           NaN             NaN     NaN
# 29                     NaN           NaN             NaN     NaN
# ...                    ...           ...             ...     ...
# 320733                 NaN           NaN             NaN     NaN
# 320734                 NaN           NaN             NaN     NaN
# 320735                 NaN           NaN             NaN     NaN
# 320736                 NaN             H             NaN     NaN
# 320737                 NaN           NaN             NaN     NaN
# 320738                 NaN           NaN             NaN     NaN
# 320739                 NaN           NaN             NaN     NaN
# 320740                 NaN           NaN             NaN     NaN
# 320741                 NaN           NaN             NaN     NaN
# 320742                 NaN             H             NaN     NaN
# 320743                   Y             H               Y       Y
# 320744                 NaN           NaN             NaN     NaN
# 320745                 NaN           NaN             NaN     NaN
# 320746                 NaN           NaN             NaN     NaN
# 320747                 NaN           NaN             NaN     NaN
# 320748                   N            UH               N       N
# 320749                 NaN           NaN             NaN     NaN
# 320750                 NaN           NaN             NaN     NaN
# 320751                 NaN           NaN             NaN     NaN
# 320752                 NaN           NaN             NaN     NaN
# 320753                 NaN           NaN             NaN     NaN
# 320754                 NaN           NaN             NaN     NaN
# 320755                 NaN           NaN             NaN     NaN
# 320756                 NaN             H             NaN     NaN
# 320757                 NaN            UH             NaN     NaN
# 320758                 NaN           NaN             NaN     NaN
# 320759                   Y            HH               N       Y
# 320760                 NaN           NaN             NaN     NaN
# 320761                 NaN           NaN             NaN     NaN
# 320762                 NaN           NaN             NaN     NaN
#
#        APP_POSITION_TYPE APP_EMP_TYPE APP_COMP_TYPE PACK
# 0                    NaN          NaN           NaN  102
# 1                    NaN          NaN           NaN  102
# 2                    NaN          NaN           NaN  102
# 3                    NaN          NaN           NaN  K01
# 4                    NaN          NaN           NaN  K01
# 5                    NaN          NaN           NaN  102
# 6                    NaN          NaN           NaN  O01
# 7                MANAGER      PRIVATE       PRIVATE  O01
# 8             SPECIALIST      PRIVATE       PRIVATE  K01
# 9                    NaN          NaN           NaN  K01
# 10            SPECIALIST      PRIVATE       PRIVATE  102
# 11                   NaN          NaN           NaN  O01
# 12                   NaN          NaN           NaN  O01
# 13               MANAGER        INTER         INTER  105
# 14                   NaN          NaN           NaN  102
# 15                   NaN          NaN           NaN  102
# 16                   NaN          NaN           NaN  K01
# 17                   NaN          NaN           NaN  102
# 18                   NaN        STATE         STATE  107
# 19                   NaN          NaN           NaN  K01
# 20                   NaN          NaN           NaN  102
# 21                   NaN          NaN           NaN  K01
# 22                   NaN          NaN           NaN  O01
# 23                   NaN          NaN           NaN  102
# 24                   NaN          NaN           NaN  K01
# 25                   NaN          NaN           NaN  102
# 26                   NaN          NaN           NaN  103
# 27                   NaN          NaN           NaN  107
# 28                   NaN          NaN           NaN  105
# 29                   NaN          NaN           NaN  K01
# ...                  ...          ...           ...  ...
# 320733               NaN          NaN           NaN  K01
# 320734               NaN          NaN           NaN  103
# 320735               NaN          NaN           NaN  K01
# 320736        SPECIALIST      PRIVATE       PRIVATE  102
# 320737               NaN          NaN           NaN  102
# 320738               NaN          NaN           NaN  102
# 320739               NaN          NaN           NaN  105
# 320740               NaN          NaN           NaN  K01
# 320741               NaN          NaN           NaN  102
# 320742        SPECIALIST      PRIVATE       PRIVATE  102
# 320743           MANAGER      PRIVATE       PRIVATE  102
# 320744               NaN          NaN           NaN  102
# 320745               NaN          NaN           NaN  102
# 320746               NaN          NaN           NaN  102
# 320747               NaN          NaN           NaN  102
# 320748               NaN        STATE         STATE  104
# 320749               NaN          NaN           NaN  K01
# 320750               NaN          NaN           NaN  102
# 320751               NaN          NaN           NaN  102
# 320752               NaN          NaN           NaN  102
# 320753               NaN          NaN           NaN  K01
# 320754               NaN          NaN           NaN  K01
# 320755               NaN          NaN           NaN  102
# 320756        SPECIALIST      PRIVATE       PRIVATE  102
# 320757        SPECIALIST      PRIVATE       PRIVATE  K01
# 320758               NaN          NaN           NaN  102
# 320759       TOP_MANAGER      PRIVATE       PRIVATE  102
# 320760               NaN          NaN           NaN  K01
# 320761               NaN          NaN           NaN  105
# 320762               NaN          NaN           NaN  102
#
# [320763 rows x 13 columns]

# %% [markdown]
# Смотрим статистику по колонкам типа object

# %%
train_df.select_dtypes(include=object).describe()
# Out:
#        CLNT_TRUST_RELATION APP_MARITAL_STATUS APP_KIND_OF_PROP_HABITATION  \
# count                62935              61775                       53722
# unique                  22                 13                           5
# top                 FRIEND                  M                          SO
# freq                 22613              27848                       25461
#
#        CLNT_JOB_POSITION_TYPE CLNT_JOB_POSITION APP_DRIVING_LICENSE  \
# count                   40522            190393               51896
# unique                      4             19053                   2
# top                SPECIALIST          ДИРЕКТОР                   N
# freq                    22741             10075               32938
#
#        APP_EDUCATION APP_TRAVEL_PASS APP_CAR APP_POSITION_TYPE APP_EMP_TYPE  \
# count          61665           51896   51895             54780        60986
# unique            17               2       2                 4            4
# top                H               N       N        SPECIALIST      PRIVATE
# freq           38499           47829   29760             33154        53529
#
#        APP_COMP_TYPE    PACK
# count          60986  320763
# unique             4      12
# top          PRIVATE     102
# freq           53529  105756

# %% [markdown]
# Если в колонке высокая гранулярность, то ее можно удалить из набора или разбить на группы

# %%
train_df.select_dtypes(include=object).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320763 entries, 0 to 320762
# Data columns (total 13 columns):
# CLNT_TRUST_RELATION            62935 non-null object
# APP_MARITAL_STATUS             61775 non-null object
# APP_KIND_OF_PROP_HABITATION    53722 non-null object
# CLNT_JOB_POSITION_TYPE         40522 non-null object
# CLNT_JOB_POSITION              190393 non-null object
# APP_DRIVING_LICENSE            51896 non-null object
# APP_EDUCATION                  61665 non-null object
# APP_TRAVEL_PASS                51896 non-null object
# APP_CAR                        51895 non-null object
# APP_POSITION_TYPE              54780 non-null object
# APP_EMP_TYPE                   60986 non-null object
# APP_COMP_TYPE                  60986 non-null object
# PACK                           320763 non-null object
# dtypes: object(13)
# memory usage: 34.3+ MB

# %% [markdown]
# Трансформируем object-колонки в числовые значения (get_dummies лучше, но сложнее. Попробовать потом!)

# %%
le = preprocessing.LabelEncoder()
for column_name in train_df.columns:
    if train_df[column_name].dtype == object:
        train_df[column_name] = le.fit_transform(train_df[column_name].astype(str)) 
    else:
        pass

# %%
train_df[object_columns].head()
# Out:
#    CLNT_TRUST_RELATION  APP_MARITAL_STATUS  APP_KIND_OF_PROP_HABITATION  \
# 0                    9                  10                            5
# 1                    9                  10                            5
# 2                    9                  10                            5
# 3                    9                  10                            5
# 4                    9                  10                            5
#
#    CLNT_JOB_POSITION_TYPE  CLNT_JOB_POSITION  APP_DRIVING_LICENSE  \
# 0                       4                357                    2
# 1                       4              16866                    2
# 2                       4              15545                    2
# 3                       4                357                    2
# 4                       4              18950                    2
#
#    APP_EDUCATION  APP_TRAVEL_PASS  APP_CAR  APP_POSITION_TYPE  APP_EMP_TYPE  \
# 0             16                2        2                  4             4
# 1             16                2        2                  4             4
# 2             16                2        2                  4             4
# 3             16                2        2                  4             4
# 4             16                2        2                  4             4
#
#    APP_COMP_TYPE  PACK
# 0              4     1
# 1              4     1
# 2              4     1
# 3              4     9
# 4              4     9

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320763 entries, 0 to 320762
# Columns: 117 entries, Unnamed: 0 to TARGET
# dtypes: float64(100), int64(17)
# memory usage: 288.8 MB

# %% [markdown]
# Выбираем колонки типа int в отдельную таблицу

# %%
train_df.select_dtypes(include=int).head(10)
# Out:
#    Unnamed: 0      ID  CR_PROD_CNT_IL  CLNT_TRUST_RELATION  \
# 0      333149  479990               0                    9
# 1      303639  450480               0                    9
# 2      327113  473954               0                    9
# 3      384197  531038               0                    9
# 4      202462  349303               0                    9
# 5       53398  200239               0                    9
# 6      251372  398213               0                    9
# 7       71572  218413               1                    9
# 8      169965  316806               3                    3
# 9      257285  404126               0                    9
#
#    APP_MARITAL_STATUS  APP_KIND_OF_PROP_HABITATION  CLNT_JOB_POSITION_TYPE  \
# 0                  10                            5                       4
# 1                  10                            5                       4
# 2                  10                            5                       4
# 3                  10                            5                       4
# 4                  10                            5                       4
# 5                  10                            5                       4
# 6                  10                            5                       4
# 7                   3                            3                       4
# 8                   6                            5                       0
# 9                  10                            5                       4
#
#    CLNT_JOB_POSITION  APP_DRIVING_LICENSE  APP_EDUCATION  APP_TRAVEL_PASS  \
# 0                357                    2             16                2
# 1              16866                    2             16                2
# 2              15545                    2             16                2
# 3                357                    2             16                2
# 4              18950                    2             16                2
# 5                357                    2             16                2
# 6               7066                    2             16                2
# 7               2563                    1             10                0
# 8              10801                    2              4                2
# 9              14064                    2             16                2
#
#    APP_CAR  APP_POSITION_TYPE  APP_EMP_TYPE  APP_COMP_TYPE  PACK  TARGET
# 0        2                  4             4              4     1       0
# 1        2                  4             4              4     1       0
# 2        2                  4             4              4     1       0
# 3        2                  4             4              4     9       0
# 4        2                  4             4              4     9       0
# 5        2                  4             4              4     1       0
# 6        2                  4             4              4    11       0
# 7        0                  0             2              2    11       0
# 8        2                  2             2              2     9       1
# 9        2                  4             4              4     9       0

# %%
train_df.select_dtypes(include=int).sort_values(by='Unnamed: 0', ascending=True).head(20)
# Out:
#         Unnamed: 0      ID  CR_PROD_CNT_IL  CLNT_TRUST_RELATION  \
# 105654           0  146841               0                    9
# 232818           1  146842               0                    9
# 56841            2  146843               0                    9
# 282521           3  146844               0                    9
# 168642           4  146845               0                    9
# 75831            6  146847               0                    9
# 48715            7  146848               0                    9
# 245254           8  146849               0                    9
# 237450           9  146850               0                    9
# 178592          10  146851               0                    9
# 47056           11  146852               0                    9
# 139850          12  146853               0                    9
# 305620          14  146855               0                    0
# 89207           16  146857               0                    3
# 109619          17  146858               0                    9
# 166618          20  146861               0                    9
# 240351          21  146862               0                    9
# 114506          22  146863               0                    3
# 268096          23  146864               0                    9
# 13597           24  146865               0                    9
#
#         APP_MARITAL_STATUS  APP_KIND_OF_PROP_HABITATION  \
# 105654                  10                            5
# 232818                  10                            5
# 56841                   10                            5
# 282521                  10                            5
# 168642                  10                            5
# 75831                   10                            5
# 48715                   10                            5
# 245254                  10                            5
# 237450                  10                            5
# 178592                  10                            5
# 47056                   10                            5
# 139850                  10                            5
# 305620                   3                            3
# 89207                    6                            2
# 109619                  10                            5
# 166618                  10                            5
# 240351                  10                            5
# 114506                   6                            0
# 268096                  10                            5
# 13597                   10                            5
#
#         CLNT_JOB_POSITION_TYPE  CLNT_JOB_POSITION  APP_DRIVING_LICENSE  \
# 105654                       4              16506                    2
# 232818                       4                357                    2
# 56841                        4               1898                    2
# 282521                       4               6169                    2
# 168642                       4                357                    2
# 75831                        4               2945                    2
# 48715                        4              17167                    2
# 245254                       4                357                    2
# 237450                       4               2266                    2
# 178592                       4                564                    2
# 47056                        4               6414                    2
# 139850                       4              13182                    2
# 305620                       2               6139                    1
# 89207                        2                357                    1
# 109619                       4               6824                    2
# 166618                       4              15858                    2
# 240351                       4               2856                    2
# 114506                       1               2563                    1
# 268096                       4              14812                    2
# 13597                        4              12478                    2
#
#         APP_EDUCATION  APP_TRAVEL_PASS  APP_CAR  APP_POSITION_TYPE  \
# 105654             16                2        2                  4
# 232818             16                2        2                  4
# 56841              16                2        2                  4
# 282521             16                2        2                  4
# 168642             16                2        2                  4
# 75831              16                2        2                  4
# 48715              16                2        2                  4
# 245254             16                2        2                  4
# 237450             16                2        2                  4
# 178592             16                2        2                  4
# 47056              16                2        2                  4
# 139850             16                2        2                  4
# 305620              5                0        0                  2
# 89207               4                0        0                  2
# 109619             16                2        2                  4
# 166618             16                2        2                  4
# 240351             16                2        2                  4
# 114506              4                0        0                  1
# 268096             16                2        2                  4
# 13597              16                2        2                  4
#
#         APP_EMP_TYPE  APP_COMP_TYPE  PACK  TARGET
# 105654             4              4     9       0
# 232818             4              4     1       0
# 56841              4              4     1       0
# 282521             4              4     9       0
# 168642             4              4     1       0
# 75831              4              4     4       0
# 48715              4              4    11       0
# 245254             4              4     1       1
# 237450             4              4    11       0
# 178592             4              4    11       0
# 47056              4              4     4       0
# 139850             4              4     9       0
# 305620             3              3     4       0
# 89207              2              2     9       0
# 109619             4              4     1       0
# 166618             4              4     1       0
# 240351             4              4     4       0
# 114506             2              2    11       0
# 268096             4              4     1       0
# 13597              4              4     1       0

# %% [markdown]
# Первые две колонки - обычные sequnces, поэтому можно удалить

# %%
train_df.drop(['Unnamed: 0','ID'], axis=1, inplace=True)
int_columns = train_df.select_dtypes(include=int).columns
train_df[int_columns].tail(20)
# Out:
#         CR_PROD_CNT_IL  CLNT_TRUST_RELATION  APP_MARITAL_STATUS  \
# 320743               1                    6                   3
# 320744               0                    9                  10
# 320745               0                    9                  10
# 320746               0                    9                  10
# 320747               0                    9                  10
# 320748               0                    4                   3
# 320749               0                    9                  10
# 320750               0                    9                  10
# 320751               0                    9                  10
# 320752               0                    9                  10
# 320753               0                    9                  10
# 320754               0                    9                  10
# 320755               0                    9                  10
# 320756               1                    3                   3
# 320757               1                    7                   4
# 320758               0                    9                  10
# 320759               0                    7                   3
# 320760               0                    9                  10
# 320761               0                    9                  10
# 320762               0                    9                  10
#
#         APP_KIND_OF_PROP_HABITATION  CLNT_JOB_POSITION_TYPE  \
# 320743                            4                       4
# 320744                            5                       4
# 320745                            5                       4
# 320746                            5                       4
# 320747                            5                       4
# 320748                            5                       4
# 320749                            5                       4
# 320750                            5                       4
# 320751                            5                       4
# 320752                            5                       4
# 320753                            5                       4
# 320754                            5                       4
# 320755                            5                       4
# 320756                            4                       0
# 320757                            4                       4
# 320758                            5                       4
# 320759                            0                       1
# 320760                            5                       4
# 320761                            5                       4
# 320762                            5                       4
#
#         CLNT_JOB_POSITION  APP_DRIVING_LICENSE  APP_EDUCATION  \
# 320743               7493                    1              4
# 320744               5194                    2             16
# 320745                357                    2             16
# 320746              17532                    2             16
# 320747               2563                    2             16
# 320748               4873                    0             10
# 320749               3413                    2             16
# 320750              17537                    2             16
# 320751                357                    2             16
# 320752              13941                    2             16
# 320753              15978                    2             16
# 320754               4614                    2             16
# 320755              16818                    2             16
# 320756               3413                    2              4
# 320757              13693                    2             10
# 320758              13275                    2             16
# 320759               3874                    1              5
# 320760              14811                    2             16
# 320761              18718                    2             16
# 320762              14281                    2             16
#
#         APP_TRAVEL_PASS  APP_CAR  APP_POSITION_TYPE  APP_EMP_TYPE  \
# 320743                1        1                  0             2
# 320744                2        2                  4             4
# 320745                2        2                  4             4
# 320746                2        2                  4             4
# 320747                2        2                  4             4
# 320748                0        0                  4             3
# 320749                2        2                  4             4
# 320750                2        2                  4             4
# 320751                2        2                  4             4
# 320752                2        2                  4             4
# 320753                2        2                  4             4
# 320754                2        2                  4             4
# 320755                2        2                  4             4
# 320756                2        2                  2             2
# 320757                2        2                  2             2
# 320758                2        2                  4             4
# 320759                0        1                  3             2
# 320760                2        2                  4             4
# 320761                2        2                  4             4
# 320762                2        2                  4             4
#
#         APP_COMP_TYPE  PACK  TARGET
# 320743              2     1       0
# 320744              4     1       0
# 320745              4     1       0
# 320746              4     1       0
# 320747              4     1       0
# 320748              3     3       0
# 320749              4     9       0
# 320750              4     1       0
# 320751              4     1       0
# 320752              4     1       0
# 320753              4     9       1
# 320754              4     9       1
# 320755              4     1       0
# 320756              2     1       0
# 320757              2     9       0
# 320758              4     1       0
# 320759              2     1       0
# 320760              4     9       0
# 320761              4     4       1
# 320762              4     1       0

# %% [markdown]
# Проверяем количество уникальных значений

# %%
for i in int_columns:
    print(train_df[i].unique().shape)
# Out:
# (12,)
# (23,)
# (14,)
# (6,)
# (5,)
# (19054,)
# (3,)
# (18,)
# (3,)
# (3,)
# (5,)
# (5,)
# (5,)
# (12,)
# (2,)

# %%
int_columns[5]
# Out:
# 'CLNT_JOB_POSITION'

# %% [markdown]
# В колонке CLNT_JOB_POSITION очень много уникальных значений - 19054

# %%
plt.plot(np.array(train_df[int_columns[5]].value_counts())[:10])

# %% [markdown]
# Некоторые значения наиболее встречающееся (>12000 с идентификатором <2), остальные редко встречаются

# %% [markdown]
# Графики разброса данных в выбранных колонках (hue - по каким значениям выводить разброс)

# %%
sns.pairplot(train_df[[int_columns[5], int_columns[1], int_columns[14]]], hue=int_columns[14])

# %% [markdown]
# Удаляем CLNT_JOB_POSITION

# %%
train_df.drop('CLNT_JOB_POSITION', axis=1, inplace=True)

# %%
train_df.shape
# Out:
# (320763, 114)

# %% [markdown]
# Выбираем колонки типа float в отдельную таблицу

# %%
float_cols = train_df.select_dtypes(float).columns

# %%
train_df.select_dtypes(float).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320763 entries, 0 to 320762
# Data columns (total 100 columns):
# AMOUNT_RUB_CLO_PRC            286213 non-null float64
# PRC_ACCEPTS_A_EMAIL_LINK      139950 non-null float64
# APP_REGISTR_RGN_CODE          54850 non-null float64
# PRC_ACCEPTS_A_POS             139950 non-null float64
# PRC_ACCEPTS_A_TK              139950 non-null float64
# TURNOVER_DYNAMIC_IL_1M        320763 non-null float64
# CNT_TRAN_AUT_TENDENCY1M       69535 non-null float64
# SUM_TRAN_AUT_TENDENCY1M       69535 non-null float64
# AMOUNT_RUB_SUP_PRC            286213 non-null float64
# PRC_ACCEPTS_A_AMOBILE         139950 non-null float64
# SUM_TRAN_AUT_TENDENCY3M       100204 non-null float64
# PRC_ACCEPTS_TK                139950 non-null float64
# PRC_ACCEPTS_A_MTP             139950 non-null float64
# REST_DYNAMIC_FDEP_1M          320763 non-null float64
# CNT_TRAN_AUT_TENDENCY3M       100204 non-null float64
# CNT_ACCEPTS_TK                139950 non-null float64
# REST_DYNAMIC_SAVE_3M          320763 non-null float64
# CR_PROD_CNT_VCU               320763 non-null float64
# REST_AVG_CUR                  320763 non-null float64
# CNT_TRAN_MED_TENDENCY1M       62457 non-null float64
# AMOUNT_RUB_NAS_PRC            286213 non-null float64
# TRANS_COUNT_SUP_PRC           286213 non-null float64
# CNT_TRAN_CLO_TENDENCY1M       59823 non-null float64
# SUM_TRAN_MED_TENDENCY1M       62457 non-null float64
# PRC_ACCEPTS_A_ATM             139950 non-null float64
# PRC_ACCEPTS_MTP               139950 non-null float64
# TRANS_COUNT_NAS_PRC           286213 non-null float64
# CNT_ACCEPTS_MTP               139950 non-null float64
# CR_PROD_CNT_TOVR              320763 non-null float64
# CR_PROD_CNT_PIL               320763 non-null float64
# SUM_TRAN_CLO_TENDENCY1M       59823 non-null float64
# TURNOVER_CC                   320763 non-null float64
# TRANS_COUNT_ATM_PRC           286213 non-null float64
# AMOUNT_RUB_ATM_PRC            286213 non-null float64
# TURNOVER_PAYM                 320763 non-null float64
# AGE                           320763 non-null float64
# CNT_TRAN_MED_TENDENCY3M       104645 non-null float64
# CR_PROD_CNT_CC                320763 non-null float64
# SUM_TRAN_MED_TENDENCY3M       104645 non-null float64
# REST_DYNAMIC_FDEP_3M          320763 non-null float64
# REST_DYNAMIC_IL_1M            320763 non-null float64
# SUM_TRAN_CLO_TENDENCY3M       103775 non-null float64
# LDEAL_TENOR_MAX               7359 non-null float64
# LDEAL_YQZ_CHRG                1135 non-null float64
# CR_PROD_CNT_CCFP              320763 non-null float64
# DEAL_YQZ_IR_MAX               7359 non-null float64
# LDEAL_YQZ_COM                 1129 non-null float64
# DEAL_YQZ_IR_MIN               7359 non-null float64
# CNT_TRAN_CLO_TENDENCY3M       103775 non-null float64
# REST_DYNAMIC_CUR_1M           320763 non-null float64
# REST_AVG_PAYM                 320763 non-null float64
# LDEAL_TENOR_MIN               7359 non-null float64
# LDEAL_AMT_MONTH               1704 non-null float64
# LDEAL_GRACE_DAYS_PCT_MED      320763 non-null float64
# REST_DYNAMIC_CUR_3M           320763 non-null float64
# CNT_TRAN_SUP_TENDENCY3M       179529 non-null float64
# TURNOVER_DYNAMIC_CUR_1M       320763 non-null float64
# REST_DYNAMIC_PAYM_3M          320763 non-null float64
# SUM_TRAN_SUP_TENDENCY3M       179529 non-null float64
# REST_DYNAMIC_IL_3M            320763 non-null float64
# CNT_TRAN_ATM_TENDENCY3M       230841 non-null float64
# CNT_TRAN_ATM_TENDENCY1M       185911 non-null float64
# TURNOVER_DYNAMIC_IL_3M        320763 non-null float64
# SUM_TRAN_ATM_TENDENCY3M       230841 non-null float64
# DEAL_GRACE_DAYS_ACC_S1X1      63615 non-null float64
# AVG_PCT_MONTH_TO_PCLOSE       1468 non-null float64
# DEAL_YWZ_IR_MIN               86488 non-null float64
# SUM_TRAN_SUP_TENDENCY1M       140850 non-null float64
# DEAL_YWZ_IR_MAX               86488 non-null float64
# SUM_TRAN_ATM_TENDENCY1M       185911 non-null float64
# REST_DYNAMIC_PAYM_1M          320763 non-null float64
# CNT_TRAN_SUP_TENDENCY1M       140850 non-null float64
# DEAL_GRACE_DAYS_ACC_AVG       62693 non-null float64
# TURNOVER_DYNAMIC_CUR_3M       320763 non-null float64
# MAX_PCLOSE_DATE               1699 non-null float64
# LDEAL_YQZ_PC                  2551 non-null float64
# CLNT_SETUP_TENOR              320763 non-null float64
# DEAL_GRACE_DAYS_ACC_MAX       62693 non-null float64
# TURNOVER_DYNAMIC_PAYM_3M      320763 non-null float64
# LDEAL_DELINQ_PER_MAXYQZ       7359 non-null float64
# TURNOVER_DYNAMIC_PAYM_1M      320763 non-null float64
# CLNT_SALARY_VALUE             652 non-null float64
# TRANS_AMOUNT_TENDENCY3M       273904 non-null float64
# MED_DEBT_PRC_YQZ              7359 non-null float64
# TRANS_CNT_TENDENCY3M          273904 non-null float64
# LDEAL_USED_AMT_AVG_YQZ        7359 non-null float64
# REST_DYNAMIC_CC_1M            320763 non-null float64
# LDEAL_USED_AMT_AVG_YWZ        86488 non-null float64
# TURNOVER_DYNAMIC_CC_1M        320763 non-null float64
# AVG_PCT_DEBT_TO_DEAL_AMT      1704 non-null float64
# LDEAL_ACT_DAYS_ACC_PCT_AVG    84414 non-null float64
# REST_DYNAMIC_CC_3M            320763 non-null float64
# MED_DEBT_PRC_YWZ              86488 non-null float64
# LDEAL_ACT_DAYS_PCT_TR3        84414 non-null float64
# LDEAL_ACT_DAYS_PCT_AAVG       88692 non-null float64
# LDEAL_DELINQ_PER_MAXYWZ       86488 non-null float64
# TURNOVER_DYNAMIC_CC_3M        320763 non-null float64
# LDEAL_ACT_DAYS_PCT_TR         84414 non-null float64
# LDEAL_ACT_DAYS_PCT_TR4        84414 non-null float64
# LDEAL_ACT_DAYS_PCT_CURR       84414 non-null float64
# dtypes: float64(100)
# memory usage: 257.2 MB

# %% [markdown]
# Почти в каждой колонке есть NaN (всего 320762)

# %%
for i in train_df.select_dtypes(float).columns:
    if len(train_df[i].unique()) < 5:
        print(i, train_df[i].unique())
# Out:
# PRC_ACCEPTS_A_EMAIL_LINK [ 0. nan]
# PRC_ACCEPTS_A_POS [ 0. nan]
# PRC_ACCEPTS_A_TK [ 0. nan]
# PRC_ACCEPTS_A_AMOBILE [ 0. nan]
# PRC_ACCEPTS_TK [ 0. nan]
# PRC_ACCEPTS_A_MTP [ 0. nan]
# CNT_ACCEPTS_TK [ 0. nan]
# PRC_ACCEPTS_A_ATM [ 0. nan]
# PRC_ACCEPTS_MTP [ 0. nan]
# CNT_ACCEPTS_MTP [ 0. nan]
# LDEAL_DELINQ_PER_MAXYQZ [nan 0.  1.  0.5]
# MED_DEBT_PRC_YQZ [nan 1.  0.  0.5]
# LDEAL_DELINQ_PER_MAXYWZ [0.  nan 0.5 1. ]

# %% [markdown]
# Видно, что в колонках с 2 уникальными значениями, только 0 и NaN. Такие колонки можно удалить

# %%
for i in train_df.select_dtypes(float).columns:
    if len(train_df[i].unique()) < 3:
        train_df.drop(i, axis=1, inplace=True)

# %%
train_df.shape
# Out:
# (320763, 104)

# %% [markdown]
# NaN во float-колонках заменяем mean-значениями

# %%
for i in train_df.select_dtypes(float).columns:
    train_df[i].fillna(train_df[i].mean(), inplace=True)
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 320763 entries, 0 to 320762
# Columns: 104 entries, CR_PROD_CNT_IL to TARGET
# dtypes: float64(90), int64(14)
# memory usage: 267.0 MB

# %%
y = train_df['TARGET']
x = train_df.drop('TARGET', axis = 1)
x.shape, y.shape
# Out:
# ((320763, 103), (320763,))

# %%
used_cols = x.columns

# %% [markdown]
# Получается 103 features

# %% [markdown]
# ### Построение модели

# %% [markdown]
# Объявление применяеных библиотек

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier as DT
from sklearn.metrics import f1_score, accuracy_score, average_precision_score,\
                            confusion_matrix, roc_curve, precision_recall_curve, auc

# %% [markdown]
# ### Decision tree

# %%
#x = train_df.drop('TARGET', axis = 1)
#y = train_df['TARGET']
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size = 0.33,
    random_state = 42)

# %% [markdown]
# Метод GridSearch для нахождения лучших параметров для decision tree

# %%
decision_tree = DT(class_weight={0: 1, 1: 10}) # 1 меньше в 10 раз, то 1 в 10 раз больший вес для балансировки

# Итерируем до подбора наиболее лучших параметров
# Когда параметры перестанут улучшаться, можно остановиться

parameters_dt = {'min_samples_leaf': [1, 10, 100], 'max_depth': [1, 10, 100]} # 9 комбинаций = 3*3

# {'max_depth': 10, 'min_samples_leaf': 100}
#parameters_dt = {'min_samples_leaf': [50, 100, 150], 'max_depth': [5, 10, 15]}
#...

dt_cv = GridSearchCV(decision_tree, param_grid = parameters_dt, scoring = 'roc_auc')
# Проводим обучение на x_train и y_train
dt_cv.fit(x_train, y_train)
print(dt_cv.best_params_)

# Получаем вероятности для наших предсказаний
probabilities_dt_cv = dt_cv.predict_proba(x_test)[:,1]
# 1 колонка - вероятность TARGET=0
# 2 колонка - вероятность TARGET=1
# Out:
# {'max_depth': 10, 'min_samples_leaf': 100}

# %%
dt_cv.predict_proba(x_test)
# Out:
# array([[0.98393832, 0.01606168],
#        [0.96742671, 0.03257329],
#        [0.88948512, 0.11051488],
#        ...,
#        [0.3937397 , 0.6062603 ],
#        [0.88948512, 0.11051488],
#        [0.46202532, 0.53797468]])

# %%
#TPR = TP/(TP+FN)
#FPR = FP/(FP+TN)

false_positive_rates_dt_cv, true_positive_rates_dt_cv, _ = roc_curve(y_test, probabilities_dt_cv)
roc_auc_dt_cv = auc(false_positive_rates_dt_cv, true_positive_rates_dt_cv)

print('ROC AUC: ', roc_auc_dt_cv)

best_params = dt_cv.best_params_
best_res = roc_auc_dt_cv
# Out:
# ROC AUC:  0.8088779522536826

# %% [markdown]
# Лучшие параметры: max_depth=11, min_samples_leaf=241, ROC AUC=0.812772233806266

# %% [markdown]
# Переопределяем decision_tree для обучения на всем train_df и предсказания на test_df

# %%
decision_tree = DT(criterion='gini', min_samples_leaf=241, max_depth=11, random_state=0, class_weight={0: 1, 1: 10})

# %%
decision_tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight={0: 1, 1: 10}, criterion='gini',
#             max_depth=11, max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=241, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %% [markdown]
# Confusion Matrix (для наглядности)

# %%
predictions_dt = decision_tree.predict(x_test)
confusion_dt = pd.DataFrame(confusion_matrix(y_test, predictions_dt))

TN, FP = confusion_dt[0][0], confusion_dt[0][1]
FN, TP = confusion_dt[1][0], confusion_dt[1][1]

print('Confusion matrix for Decision Tree:')
data = np.array([['','Predicted Zeros','Predicted Ones'],
            ['Zeros',TN,FP],
            ['Ones',FN,TP]])

print(pd.DataFrame(data=data[1:,1:],
              index=data[1:,0],
              columns=data[0,1:]))
# Out:
# Confusion matrix for Decision Tree:
#       Predicted Zeros Predicted Ones
# Zeros           68128           1947
# Ones            28997           6780

# %%
probabilities_dt = decision_tree.predict_proba(x_test)[:,1]
false_positive_rates_dt, true_positive_rates_dt, _ = roc_curve(y_test, probabilities_dt)
roc_auc_dt = auc(false_positive_rates_dt, true_positive_rates_dt)
print('ROC AUC: ', roc_auc_dt)
# Out:
# ROC AUC:  0.8112300148697535

# %% [markdown]
# ### Применяем обучения для test_df

# %%
train_df = pd.read_csv(train_dir)
test_df = pd.read_csv(test_dir)
train_df = train_df[train_df['TARGET'].notna()]
train_df['TARGET'] = train_df['TARGET'].round(0).astype(int)
y_train = train_df['TARGET']
train_df = train_df.drop('TARGET', axis = 1)

# %%
# В наборах train и  test оставляем только features-колонки,
# полученные после клинзинга данных (In[60])
train_df = train_df[used_cols] 
test_df = test_df[used_cols]
train_df.shape, test_df.shape
# Out:
# ((320763, 103), (44399, 103))

# %%
concat_df = pd.concat([train_df,test_df])

# %%
le = preprocessing.LabelEncoder()
for column_name in concat_df.columns:
    if train_df[column_name].dtype == object:
        # Чтобы замена object была унифицирована в разрезе двух массивов, используем конкатенированный массив
        le.fit(concat_df[column_name].astype(str)) 
        train_df[column_name] = le.transform(train_df[column_name].astype(str))
        test_df[column_name] = le.transform(test_df[column_name].astype(str)) 
        
for i in train_df.select_dtypes(float).columns:
    # Чтобы ускорить замену, mean() делаем по train_df, а не concat_df
    train_df[i].fillna(train_df[i].mean(), inplace=True)
    test_df[i].fillna(train_df[i].mean(), inplace=True)

x_train = train_df
x_test = test_df
x_train.shape, x_test.shape
# Out:
# ((320763, 103), (44399, 103))

# %% [markdown]
# ### Desision tree

# %%
decision_tree = DT(criterion='gini', min_samples_leaf=241, max_depth=11, random_state=0, class_weight={0: 1, 1: 10})

# %%
decision_tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight={0: 1, 1: 10}, criterion='gini',
#             max_depth=11, max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=241, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
probabilities_decision_tree = decision_tree.predict_proba(x_test)[:,1]

# %%
A = np.array(pd.read_csv(test_dir)['ID']).astype(str)

# %%
B = np.array(probabilities_decision_tree)

# %%
result = pd.DataFrame(np.vstack([A,B]).T, columns=['id', 'target'])

# %%
result.head()
# Out:
#        id               target
# 0  519130   0.6408094435075885
# 1  234045   0.1751472142533595
# 2  401256  0.03964882469555367
# 3  551070  0.02154328241284763
# 4  367285  0.01464741577735928

# %%
result.to_csv('lab04.csv',sep='\t', index=False)

# %% [markdown]
# Построение ROC curve

# %%
fig = plt.figure(figsize=(14, 7))

plot_crv = fig.add_subplot(121,
                       xlabel="FPR", xlim=(-.01, 1.01),
                       ylabel="TPR", ylim=(-.01, 1.01), title = 'ROC curve for Decision Tree')

plot_crv.plot(false_positive_rates_dt_cv, true_positive_rates_dt_cv,
          color='darkgreen', lw=2, label = 'ROC-curve new (AUC = %0.2f)' % roc_auc_dt_cv)
plot_crv.plot([0, 1], [0, 1], color='navy', lw=2, linestyle=':')
plt.legend(loc="lower right")
plt.show()
